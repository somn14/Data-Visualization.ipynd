# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_csv('/content/data.csv')
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.head(5)
df.tail(6)
# Out:
#       id  season       city        date                  team1  \
# 571  572    2016    Kolkata  2016-05-22  Kolkata Knight Riders
# 572  573    2016     Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016      Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27          Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 571          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.shape
# Out:
# (577, 18)

# %%
df['team1'],[df['team2']]
# Out:
# (0      Kolkata Knight Riders
#  1        Chennai Super Kings
#  2           Rajasthan Royals
#  3             Mumbai Indians
#  4            Deccan Chargers
#                 ...
#  572         Delhi Daredevils
#  573            Gujarat Lions
#  574      Sunrisers Hyderabad
#  575            Gujarat Lions
#  576      Sunrisers Hyderabad
#  Name: team1, Length: 577, dtype: object,
#  [0      Royal Challengers Bangalore
#   1                  Kings XI Punjab
#   2                 Delhi Daredevils
#   3      Royal Challengers Bangalore
#   4            Kolkata Knight Riders
#                     ...
#   572    Royal Challengers Bangalore
#   573    Royal Challengers Bangalore
#   574          Kolkata Knight Riders
#   575            Sunrisers Hyderabad
#   576    Royal Challengers Bangalore
#   Name: team2, Length: 577, dtype: object])

# %%
df['season'],[df['winner']],[df['player_of_match']]
# Out:
# (0      2008
#  1      2008
#  2      2008
#  3      2008
#  4      2008
#         ...
#  572    2016
#  573    2016
#  574    2016
#  575    2016
#  576    2016
#  Name: season, Length: 577, dtype: int64,
#  [0            Kolkata Knight Riders
#   1              Chennai Super Kings
#   2                 Delhi Daredevils
#   3      Royal Challengers Bangalore
#   4            Kolkata Knight Riders
#                     ...
#   572    Royal Challengers Bangalore
#   573    Royal Challengers Bangalore
#   574            Sunrisers Hyderabad
#   575            Sunrisers Hyderabad
#   576            Sunrisers Hyderabad
#   Name: winner, Length: 577, dtype: object],
#  [0         BB McCullum
#   1          MEK Hussey
#   2         MF Maharoof
#   3          MV Boucher
#   4           DJ Hussey
#               ...
#   572           V Kohli
#   573    AB de Villiers
#   574      MC Henriques
#   575         DA Warner
#   576       BCJ Cutting
# ...

# %%
df['win_by_runs'].max()
# Out:
# 144

# %%
df['win_by_runs'].mean()
# Out:
# 13.7157712305026

# %%
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     12
# int64       5
# float64     1
# Name: count, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=577, step=1)

# %%
df['season'].describe()
# Out:
# count     577.000000
# mean     2012.029463
# std         2.486247
# min      2008.000000
# 25%      2010.000000
# 50%      2012.000000
# 75%      2014.000000
# max      2016.000000
# Name: season, dtype: float64

# %%
df.sort_values(by='season')
# Out:
#       id  season        city        date                        team1  \
# 0      1    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 31    32    2008     Chennai  2008-05-10          Chennai Super Kings
# 32    33    2008   Hyderabad  2008-05-11        Kolkata Knight Riders
# 33    34    2008      Jaipur  2008-05-11             Delhi Daredevils
# 34    35    2008  Chandigarh  2008-05-12  Royal Challengers Bangalore
# ..   ...     ...         ...         ...                          ...
# 541  542    2016        Pune  2016-04-29      Rising Pune Supergiants
# 542  543    2016       Delhi  2016-04-30             Delhi Daredevils
# 543  544    2016   Hyderabad  2016-04-30          Sunrisers Hyderabad
# 545  546    2016        Pune  2016-05-01      Rising Pune Supergiants
# 576  577    2016   Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.sort_values(by='season').head()
# Out:
#     id  season        city        date                        team1  \
# 0    1    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 31  32    2008     Chennai  2008-05-10          Chennai Super Kings
# 32  33    2008   Hyderabad  2008-05-11        Kolkata Knight Riders
# 33  34    2008      Jaipur  2008-05-11             Delhi Daredevils
# 34  35    2008  Chandigarh  2008-05-12  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 31              Kings XI Punjab              Kings XI Punjab         field
# 32              Deccan Chargers        Kolkata Knight Riders           bat
# 33             Rajasthan Royals             Rajasthan Royals         field
# 34              Kings XI Punjab  Royal Challengers Bangalore           bat
#
#     result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.sort_values(by='season').tail()
# Out:
#       id  season       city        date                    team1  \
# 541  542    2016       Pune  2016-04-29  Rising Pune Supergiants
# 542  543    2016      Delhi  2016-04-30         Delhi Daredevils
# 543  544    2016  Hyderabad  2016-04-30      Sunrisers Hyderabad
# 545  546    2016       Pune  2016-05-01  Rising Pune Supergiants
# 576  577    2016  Bangalore  2016-05-29      Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 541                Gujarat Lions                Gujarat Lions         field
# 542        Kolkata Knight Riders        Kolkata Knight Riders         field
# 543  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 545               Mumbai Indians               Mumbai Indians         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.sort_values(by='season',ascending=False).head()
# Out:
#       id  season       city        date                        team1  \
# 576  577    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
# 546  547    2016  Bangalore  2016-05-02  Royal Challengers Bangalore
# 544  545    2016     Rajkot  2016-05-01              Kings XI Punjab
# 543  544    2016  Hyderabad  2016-04-30          Sunrisers Hyderabad
# 542  543    2016      Delhi  2016-04-30             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
# 546        Kolkata Knight Riders        Kolkata Knight Riders         field
# 544                Gujarat Lions                Gujarat Lions         field
# 543  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 542        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#      result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.sort_values(by='season',ascending=True).head()
# Out:
#     id  season        city        date                        team1  \
# 0    1    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 31  32    2008     Chennai  2008-05-10          Chennai Super Kings
# 32  33    2008   Hyderabad  2008-05-11        Kolkata Knight Riders
# 33  34    2008      Jaipur  2008-05-11             Delhi Daredevils
# 34  35    2008  Chandigarh  2008-05-12  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 31              Kings XI Punjab              Kings XI Punjab         field
# 32              Deccan Chargers        Kolkata Knight Riders           bat
# 33             Rajasthan Royals             Rajasthan Royals         field
# 34              Kings XI Punjab  Royal Challengers Bangalore           bat
#
#     result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
df['season'].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
dt=df.dropna()
print(dt.to_string())
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
dt=df.dropna()
dt=df.fillna(50,inplace=False)
print(dt.to_string())
# Out:
#       id  season            city        date                        team1                        team2                  toss_winner toss_decision     result  dl_applied                       winner  win_by_runs  win_by_wickets    player_of_match                                                 venue                umpire1          umpire2  umpire3
# 0      1    2008       Bangalore  2008-04-18        Kolkata Knight Riders  Royal Challengers Bangalore  Royal Challengers Bangalore         field     normal           0        Kolkata Knight Riders          140               0        BB McCullum                                 M Chinnaswamy Stadium              Asad Rauf      RE Koertzen     50.0
# ...

# %%
df.fillna(100,inplace=True)
print(df)
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df['season'].fillna(100,inplace=True)
print(df)
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df['season'].fillna(100,inplace=True)
print(df)
df.describe()
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.nunique()
# Out:
# id                 577
# season               9
# city                31
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              14
# win_by_runs         83
# win_by_wickets      11
# player_of_match    188
# venue               35
# umpire1             43
# umpire2             45
# umpire3              1
# dtype: int64

# %%
df.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 572  False   False  False  False  False  False        False          False
# 573  False   False  False  False  False  False        False          False
# 574  False   False  False  False  False  False        False          False
# 575  False   False  False  False  False  False        False          False
# 576  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
print(df.iloc[0])
# Out:
# id                                           1
# season                                    2008
# city                                 Bangalore
# date                                2008-04-18
# team1                    Kolkata Knight Riders
# team2              Royal Challengers Bangalore
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# result                                  normal
# dl_applied                                   0
# winner                   Kolkata Knight Riders
# win_by_runs                                140
# win_by_wickets                               0
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# umpire3                                  100.0
# Name: 0, dtype: object

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                           winner  win_by_wickets  win_by_runs  \
# 0          Kolkata Knight Riders               0          140
# 1            Chennai Super Kings               0           33
# 2               Delhi Daredevils               9            0
# 3    Royal Challengers Bangalore               5            0
# 4          Kolkata Knight Riders               5            0
# ..                           ...             ...          ...
# 572  Royal Challengers Bangalore               6            0
# 573  Royal Challengers Bangalore               4            0
# 574          Sunrisers Hyderabad               0           22
# 575          Sunrisers Hyderabad               4            0
# 576          Sunrisers Hyderabad               0            8
#
#                                                 venue  umpire3  \
# 0                               M Chinnaswamy Stadium    100.0
# 1          Punjab Cricket Association Stadium, Mohali    100.0
# ...

# %%
df.sort_index(axis=1,ascending=False)
print(df.iloc[1:4,1:4])
# Out:
#    season        city        date
# 1    2008  Chandigarh  2008-04-19
# 2    2008       Delhi  2008-04-19
# 3    2008      Mumbai  2008-04-20

# %%
sns.pairplot(df,hue='team1')

# %%
sns.barplot(x='season',y='team2',data=df)
# Out:
# <Axes: xlabel='season', ylabel='team2'>

# %%
sns.jointplot(x='season',y='team1',data=df)

# %%
import matplotlib.pyplot as plt
