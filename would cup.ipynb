# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl

# %%
df=pd.read_csv('/content/would cup.csv')
df
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
df.tail()
# Out:
#      Year              Datetime                     Stage  \
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
df.head()
df.tail()
# Out:
#      Year              Datetime                     Stage  \
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
# Print each column name
print("Column names:")
for col in df.columns:
  print(col)
# Out:
# Column names:
# Year
# Datetime
# Stage
# Stadium
# City
# Home Team Name
# Home Team Goals
# Away Team Goals
# Away Team Name
# Win conditions
# Attendance
# Half-time Home Goals
# Half-time Away Goals
# Referee
# Assistant 1
# Assistant 2
# RoundID
# MatchID
# Home Team Initials
# Away Team Initials

# %%
#slicing
df[55:90]
# Out:
#     Year              Datetime    Stage  \
# 55  1950  25 Jun 1950 - 15:00   Group 2
# 56  1950  25 Jun 1950 - 15:00   Group 3
# 57  1950  25 Jun 1950 - 15:00   Group 1
# 58  1950  28 Jun 1950 - 15:00   Group 1
# 59  1950  28 Jun 1950 - 15:00   Group 1
# 60  1950  29 Jun 1950 - 15:00   Group 2
# 61  1950  29 Jun 1950 - 15:30   Group 3
# 62  1950  29 Jun 1950 - 15:00   Group 2
# 63  1950  01 Jul 1950 - 15:00   Group 1
# 64  1950  02 Jul 1950 - 15:00   Group 2
# 65  1950  02 Jul 1950 - 15:00   Group 3
# 66  1950  02 Jul 1950 - 15:00   Group 4
# 67  1950  02 Jul 1950 - 15:40   Group 1
# 68  1950  02 Jul 1950 - 15:00   Group 2
# 69  1950  09 Jul 1950 - 15:00   Group 6
# 70  1950  09 Jul 1950 - 15:00   Group 6
# 71  1950  13 Jul 1950 - 15:00   Group 6
# 72  1950  13 Jul 1950 - 15:00   Group 6
# 73  1950  16 Jul 1950 - 15:00   Group 6
# 74  1950  16 Jul 1950 - 15:00   Group 6
# 75  1954  16 Jun 1954 - 18:00   Group 3
# 76  1954  16 Jun 1954 - 18:00   Group 3
# ...

# %%
#slicing
df[200:]
# Out:
#      Year              Datetime                     Stage  \
# 200  1970  31 May 1970 - 12:00                    Group 1
# 201  1970  02 Jun 1970 - 16:00                    Group 2
# 202  1970  02 Jun 1970 - 16:00                    Group 4
# 203  1970  02 Jun 1970 - 16:00                    Group 3
# 204  1970  03 Jun 1970 - 16:00                    Group 2
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                      Stadium             City Home Team Name  Home Team Goals  \
# 200           Estadio Azteca     Mexico City          Mexico                0
# 201               Cuauhtemoc          Puebla         Uruguay                2
# ...

# %%
#slicing
df[:254]
# Out:
#      Year               Datetime    Stage           Stadium            City  \
# 0    1930   13 Jul 1930 - 15:00   Group 1           Pocitos     Montevideo
# 1    1930   13 Jul 1930 - 15:00   Group 4    Parque Central     Montevideo
# 2    1930   14 Jul 1930 - 12:45   Group 2    Parque Central     Montevideo
# 3    1930   14 Jul 1930 - 14:50   Group 3           Pocitos     Montevideo
# 4    1930   15 Jul 1930 - 16:00   Group 1    Parque Central     Montevideo
# ..    ...                    ...      ...               ...             ...
# 249  1974   22 Jun 1974 - 16:00   Group 1    Olympiastadion    Berlin West
# 250  1974   22 Jun 1974 - 16:00   Group 2       Parkstadion  Gelsenkirchen
# 251  1974  22 June 1974 - 19:30   Group 1  Volksparkstadion        Hamburg
# 252  1974   23 Jun 1974 - 16:00   Group 3  Westfalenstadion       Dortmund
# 253  1974   23 Jun 1974 - 16:00   Group 4    Olympiastadion         Munich
#
# ...

# %%
#print a particular column
df['Stadium']
# Out:
# 0                  Pocitos
# 1           Parque Central
# 2           Parque Central
# 3                  Pocitos
# 4           Parque Central
#               ...
# 847       Arena Fonte Nova
# 848       Estadio Mineirao
# 849     Arena de Sao Paulo
# 850       Estadio Nacional
# 851    Estadio do Maracana
# Name: Stadium, Length: 852, dtype: object

# %%
[df['Attendance'].max()]#It is used to return the maximum value of each column in a DataFrame.
# Out:
# [173850.0]

# %%
[df['Attendance'].min()]#It is used to find the minimum value in each column of a DataFrame.
# Out:
# [2000.0]

# %%
[df['Attendance'].mean()]# It is used to calculate the mean (average) value of each numerical column in a DataFrame
# Out:
# [45164.8]

# %%
df.shape #It is used to get the dimensions of a DataFrame.
# Out:
# (852, 20)

# %%
df.describe() #It is used to generate descriptive statistics of a DataFrame.
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
df.describe() #It is used to generate descriptive statistics of a DataFrame.
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
df.index #index of any particular dataset
# Out:
# RangeIndex(start=0, stop=852, step=1)

# %%
df.dtypes #It is used to get the data types of each column in a DataFrame
# Out:
# Year                      int64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals           int64
# Away Team Goals           int64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals      int64
# Half-time Away Goals      int64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                   int64
# MatchID                   int64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
df.dtypes.value_counts() #It returns how many variables in each data type
# Out:
# object     12
# int64       7
# float64     1
# Name: count, dtype: int64

# %%
df['Home Team Goals'].describe()
# Out:
# count    852.000000
# mean       1.811033
# std        1.610255
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       10.000000
# Name: Home Team Goals, dtype: float64

# %%
df['Away Team Goals'].value_counts()
# Out:
# Away Team Goals
# 1    323
# 0    313
# 2    140
# 3     52
# 4     14
# 5      7
# 7      3
# Name: count, dtype: int64

# %%
df.nunique() #It is used to count the number of unique values in each column of a DataFrame
# Out:
# Year                     20
# Datetime                602
# Stage                    23
# Stadium                 181
# City                    151
# Home Team Name           78
# Home Team Goals          11
# Away Team Goals           7
# Away Team Name           83
# Win conditions           43
# Attendance              622
# Half-time Home Goals      7
# Half-time Away Goals      6
# Referee                 366
# Assistant 1             387
# Assistant 2             408
# RoundID                 101
# MatchID                 836
# Home Team Initials       77
# Away Team Initials       82
# dtype: int64

# %%
df.isnull() #It is used to detect missing values in a DataFrame.
# Out:
#       Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0    False     False  False    False  False           False            False
# 1    False     False  False    False  False           False            False
# 2    False     False  False    False  False           False            False
# 3    False     False  False    False  False           False            False
# 4    False     False  False    False  False           False            False
# ..     ...       ...    ...      ...    ...             ...              ...
# 847  False     False  False    False  False           False            False
# 848  False     False  False    False  False           False            False
# 849  False     False  False    False  False           False            False
# 850  False     False  False    False  False           False            False
# 851  False     False  False    False  False           False            False
#
# ...

# %%
df.isnull().sum() #It returns a Series where the index is the column names and the values are the number of missing values in each column
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
dt=df.dropna()
print(dt.to_string())
# Out:
#      Year               Datetime                     Stage                                             Stadium                                City              Home Team Name  Home Team Goals  Away Team Goals              Away Team Name                                 Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals                               Referee                           Assistant 1                           Assistant 2   RoundID    MatchID Home Team Initials Away Team Initials
# ...

# %%
dt=df.fillna(50,inplace=True)
print(dt)
# Out:
# None

# %%
dt=df.fillna(50,inplace=False)
print(dt)
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
df["Attendance"].fillna(50,inplace=True)
print(df)
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
x=df["Attendance"].mean()
df["Attendance"].fillna(x,inplace=True)
print(x)
print(df)
# Out:
# 45058.896713615024
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
x=df["Attendance"].median()
df["Attendance"].fillna(x,inplace=True)
print(x)
print(df)
# Out:
# 41441.5
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
#pairplot
sns.pairplot(df,hue='Year')

# %%
#pairplot
sns.pairplot(df,hue='Home Team Goals') # Removed the non-breaking space character

# %%
#pairplot
sns.pairplot(df,hue='Attendance')

# %%
#pairplot
sns.pairplot(df,hue='Attendance',palette='Reds')

# %%
#barplot
sns.barplot()
# Out:
# <Axes: >

# %%
#barrplot
sns.barplot(x='Home Team Goals',y='Away Team Goals',data=df)
# Out:
# <Axes: xlabel='Home Team Goals', ylabel='Away Team Goals'>

# %%
#barplot
sns.barplot(x='Year',y='Home Team Goals',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Home Team Goals'>

# %%
#barplot
sns.barplot(x='Year',y='Away Team Goals',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Away Team Goals'>

# %%
#jointplot
sns.jointplot(x='Home Team Goals',y='Away Team Goals',data=df)

# %%
#jointplot
sns.jointplot(x='Year',y='Away Team Goals',data=df)

# %%
#scatterplot
sns.scatterplot(x='RoundID',y='MatchID',data=df)
# Out:
# <Axes: xlabel='RoundID', ylabel='MatchID'>

# %%
#scatterplot
sns.scatterplot(x='Year',y='Attendance',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Attendance'>

# %%
#scatterplot
sns.scatterplot(x='Year',y='Attendance',data=df,hue='Stage')
# Out:
# <Axes: xlabel='Year', ylabel='Attendance'>

# %%
#scatterplot
sns.scatterplot(x='Home Team Goals',y='Away Team Goals',data=df,hue='Year')
# Out:
# <Axes: xlabel='Home Team Goals', ylabel='Away Team Goals'>

# %%
#histplot
sns.histplot(x='Year',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
#histplot
sns.histplot(x='Attendance',data=df)
# Out:
# <Axes: xlabel='Attendance', ylabel='Count'>

# %%
#displot
sns.displot(x='Home Team Goals',data=df)

# %%
#displot
sns.displot(x='Away Team Goals',data=df)

# %%
#boxplot
sns.boxplot(x='Year',data=df)
# Out:
# <Axes: xlabel='Year'>

# %%
#boxplot
sns.boxplot(x='Away Team Goals',data=df)
# Out:
# <Axes: xlabel='Away Team Goals'>

# %%
corr=df[['Year','Attendance','Home Team Goals']].corr()
print(corr)
# Out:
#                      Year  Attendance  Home Team Goals
# Year             1.000000    0.306933        -0.381332
# Attendance       0.306933    1.000000        -0.117769
# Home Team Goals -0.381332   -0.117769         1.000000

# %%
#heatmap
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
corr=df[['Away Team Goals','RoundID','MatchID']].corr()
print(corr)
# Out:
#                  Away Team Goals   RoundID   MatchID
# Away Team Goals         1.000000 -0.005345  0.082687
# RoundID                -0.005345  1.000000  0.071549
# MatchID                 0.082687  0.071549  1.000000

# %%
#heatmap
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
# Matches Played in Different Cities
import matplotlib.pyplot as plt
matches_per_city = df['City'].value_counts()
plt.figure(figsize=(14, 7))
plt.bar(matches_per_city.index[:20], matches_per_city.values[:20])  # Show top 20 cities
plt.title('Matches Played in Different Cities (Top 20)')
plt.xlabel('City')
plt.ylabel('Number of Matches')
plt.xticks(matches_per_city.index[:20], rotation=90)
plt.show()

# %%
# Number of Matches in Different Stages
matches_per_stage = df['Stage'].value_counts()
plt.figure(figsize=(14, 7))
plt.bar(matches_per_stage.index, matches_per_stage.values, color='orange')
plt.title('Number of Matches in Different Stages')
plt.xlabel('Stage')
plt.ylabel('Number of Matches')
plt.xticks(matches_per_stage.index, rotation=45)
plt.show()

# %%
# Number of Goals Scored by Home Teams vs. Away Teams
goals_data = df[['Home Team Goals', 'Away Team Goals']].sum()
plt.figure(figsize=(10, 5))
plt.bar(goals_data.index, goals_data.values, color=['blue', 'red'])
plt.title('Total Goals Scored by Home Teams vs. Away Teams')
plt.xlabel('Team Type')
plt.ylabel('Total Goals Scored')
plt.show()

# %%
# Select only the numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

# %%
# Calculate the correlation matrix on the numeric DataFrame
correlation_matrix = numeric_df.corr()

# %%
print("Correlation coefficients:")
print(correlation_matrix)
# Out:
# Correlation coefficients:
#                           Year  Home Team Goals  Away Team Goals  Attendance  \
# Year                  1.000000        -0.381332         0.075339    0.306933
# Home Team Goals      -0.381332         1.000000         0.012474   -0.117769
# Away Team Goals       0.075339         0.012474         1.000000   -0.029581
# Attendance            0.306933        -0.117769        -0.029581    1.000000
# Half-time Home Goals -0.288909         0.729536        -0.006304   -0.122722
# Half-time Away Goals  0.020934        -0.009530         0.693780   -0.034170
# RoundID               0.343106        -0.110075        -0.005345    0.070799
# MatchID               0.636591        -0.196100         0.082687    0.153402
#
#                       Half-time Home Goals  Half-time Away Goals   RoundID  \
# Year                             -0.288909              0.020934  0.343106
# Home Team Goals                   0.729536             -0.009530 -0.110075
# ...
